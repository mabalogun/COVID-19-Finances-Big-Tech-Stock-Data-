# %% [markdown]
# # # Big Tech and COVID-19

# %% [markdown]
# The effects of COVID-19 are having a significant impact on the technology sector, affecting raw materials supply, disrupting the electronics value chain, and causing an inflationary risk on products. More positively, the disruption has caused an acceleration of remote working, and a rapid focus on evaluating and de-risking the end-to-end value chain. In addition, potential carbon emission reductions could result in renewed focus on sustainability practices. This article considers the shifting landscape across a number of areas, including:
#
# Coronavirus disease 2019 (COVID-19), also known as the coronavirus, or COVID, is a contagious disease caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The first known case was identified in Wuhan, China, in December 2019.[7] The disease has since spread worldwide, leading to an ongoing pandemic.
#
# The World Health Organization declared a Public Health Emergency of International Concern regarding COVID-19 on 30 January 2020, and later declared a pandemic on 11 March 2020. As of 31 May 2021, more than 170 million cases have been confirmed, with more than 3.54 million confirmed deaths attributed to COVID-19, making it one of the deadliest pandemics in history.
#
# COVID-19 is not only a global pandemic and public health crisis; it has also severely affected the global economy and financial markets. Significant reductions in income, a rise in unemployment, and disruptions in the transportation, service, and manufacturing industries are among the consequences of the disease mitigation measures that have been implemented in many countries. It has become clear that most governments in the world underestimated the risks of rapid COVID-19 spread and were mostly reactive in their crisis response.
#
# The outbreak is a major destabilising threat to the global economy. One estimate from an expert at Washington University in St. Louis gave a $300+ billion impact on the world's supply chain that could last up to two years.[526] Global stock markets fell on 24 February due to a significant rise in the number of COVID-19 cases outside China.[527][528] On 27 February, due to mounting worries about the COVID-19 outbreak, U.S. stock indexes posted their sharpest falls since 2008, with the Dow falling 1,191 points (the largest one-day drop since the financial crisis of 2007–08)[529] and all three major indexes ending the week down more than 10 percent.[530] On 28 February, Scope Ratings GmbH affirmed China's sovereign credit rating but maintained a Negative Outlook.[531] Stocks plunged again due to coronavirus fears, the largest fall being on 16 March.[532]
#
# Lifestyle change adaptation during the pandemic
# The pandemic has resulted in many people adapting to massive changes in life, from increased internet commerce activity to the job market. Social distancing has caused increased sales from large e-commerce companies such as Amazon, Alibaba, and Coupang.

# %%
import yfinance as yf
import pandas as pd

# %%
AAPL = yf.Ticker("AAPL")
GOOGL= yf.Ticker("GOOGL")
AMZN = yf.Ticker("AMZN")
FB = yf.Ticker("FB")
MSFT = yf.Ticker("MSFT")
NFLX = yf.Ticker("NFLX")

# %%
Apple = AAPL.history(period="2y")
Google = GOOGL.history(period="2y")
Amazon = AMZN.history(period="2y")
Facebook = FB.history(period="2y")
Microsoft = MSFT.history(period="2y")
Netflix = NFLX.history(period="2y")

# %%
tickers = ['Amazon', 'Apple', 'Facebook', 'Google', 'Microsoft', 'Netflix']

# %%
stocks =pd.concat([Amazon, Apple, Facebook, Google, Microsoft, Netflix],axis=1,keys=tickers)

# %%
stocks.columns.names = ['Ticker','Stock Info']

# %%
stocks.head()
# Out:
# Ticker           Amazon                                                  \
# Stock Info         Open         High          Low        Close   Volume
# Date
# 2019-05-29  1823.119995  1830.000000  1807.530029  1819.189941  4279000
# 2019-05-30  1825.489990  1829.469971  1807.829956  1816.319946  3146900
# 2019-05-31  1790.010010  1795.589966  1772.699951  1775.069946  4618800
# 2019-06-03  1760.010010  1766.290039  1672.000000  1692.689941  9098700
# 2019-06-04  1699.239990  1730.819946  1680.890015  1729.560059  5679100
#
# Ticker                                 Apple                        ...  \
# Stock Info Dividends Stock Splits       Open       High        Low  ...
# Date                                                                ...
# 2019-05-29         0            0  43.293122  44.012140  43.190055  ...
# 2019-05-30         0            0  43.668584  43.982693  43.354475  ...
# 2019-05-31         0            0  43.246500  43.678403  42.942209  ...
# ...

# %% [markdown]
# EDA

# %%
stocks.xs(key='Close',axis=1,level='Stock Info').min()
# Out:
# Ticker
# Amazon       1676.609985
# Apple          42.527481
# Facebook      146.009995
# Google       1038.739990
# Microsoft     117.247993
# Netflix       254.589996
# dtype: float64

# %%
stocks.xs(key='Close',axis=1,level='Stock Info').idxmin()
# Out:
# Ticker
# Amazon      2020-03-12
# Apple       2019-06-03
# Facebook    2020-03-16
# Google      2019-06-03
# Microsoft   2019-06-03
# Netflix     2019-09-24
# dtype: datetime64[ns]

# %%
stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Ticker
# Amazon       3531.449951
# Apple         142.704010
# Facebook      332.750000
# Google       2392.760010
# Microsoft     261.366486
# Netflix       586.340027
# dtype: float64

# %%
stocks.xs(key='Close',axis=1,level='Stock Info').idxmax()
# Out:
# Ticker
# Amazon      2020-09-02
# Apple       2021-01-26
# Facebook    2021-05-27
# Google      2021-04-29
# Microsoft   2021-04-27
# Netflix     2021-01-20
# dtype: datetime64[ns]

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             Amazon Return  Apple Return  Facebook Return  Google Return  \
# Date
# 2019-05-29            NaN           NaN              NaN            NaN
# 2019-05-30      -0.001578      0.005187         0.004501       0.001313
# 2019-05-31      -0.022711     -0.018115        -0.030272      -0.013296
# 2019-06-03      -0.046409     -0.010110        -0.075055      -0.061238
# 2019-06-04       0.021782      0.036584         0.020408       0.015163
#
#             Microsoft Return  Netflix Return
# Date
# 2019-05-29               NaN             NaN
# 2019-05-30          0.006323        0.007618
# 2019-05-31         -0.016305       -0.024357
# 2019-06-03         -0.031048       -0.019372
# 2019-06-04          0.027704        0.049817

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %matplotlib inline 

import plotly
import cufflinks as cf
# Out:
# C:\Users\MB\Miniconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
sns.pairplot(returns[1:])

# %%
for tick in tickers:
    stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
stocks.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# plotly
stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="abd08913-2461-43b3-b1cf-47e9ae61c177" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.heatmap(stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Ticker', ylabel='Ticker'>

# %%
sns.clustermap(stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
returns.reset_index(inplace=True)

# %%
returns.head()
# Out:
#         Date  Amazon Return  Apple Return  Facebook Return  Google Return  \
# 0 2019-05-29            NaN           NaN              NaN            NaN
# 1 2019-05-30      -0.001578      0.005187         0.004501       0.001313
# 2 2019-05-31      -0.022711     -0.018115        -0.030272      -0.013296
# 3 2019-06-03      -0.046409     -0.010110        -0.075055      -0.061238
# 4 2019-06-04       0.021782      0.036584         0.020408       0.015163
#
#    Microsoft Return  Netflix Return
# 0               NaN             NaN
# 1          0.006323        0.007618
# 2         -0.016305       -0.024357
# 3         -0.031048       -0.019372
# 4          0.027704        0.049817

# %%
returns['Date'].iloc[0]
# Out:
# Timestamp('2019-05-29 00:00:00')

# %%
time = returns['Date']

# %%
time.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-0acc59b0b258> in <module>
# ----> 1 time.month
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
#returns['Hour'] = returns['Date'].apply(lambda time: time.hour)
returns['Month'] = returns['Date'].apply(lambda time: time.month)
returns['Day of Week'] = returns['Date'].apply(lambda time: time.dayofweek)

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
returns['Day of Week'] = returns['Day of Week'].map(dmap)

# %%
dmap1 = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'June',7:'July',8: 'Aug',9: 'Sept',10: 'Oct',11: 'Nov',12: 'Dec' }

# %%
returns['Month'] = returns['Month'].map(dmap1)

# %%
returns
# Out:
#           Date  Amazon Return  Apple Return  Facebook Return  Google Return  \
# 0   2019-05-29            NaN           NaN              NaN            NaN
# 1   2019-05-30      -0.001578      0.005187         0.004501       0.001313
# 2   2019-05-31      -0.022711     -0.018115        -0.030272      -0.013296
# 3   2019-06-03      -0.046409     -0.010110        -0.075055      -0.061238
# 4   2019-06-04       0.021782      0.036584         0.020408       0.015163
# ..         ...            ...           ...              ...            ...
# 501 2021-05-24       0.013084      0.013314         0.026563       0.029166
# 502 2021-05-25       0.004333     -0.001574         0.009734       0.000775
# 503 2021-05-26       0.001875     -0.000394        -0.000397       0.007381
# 504 2021-05-27      -0.010734     -0.012377         0.015534      -0.007407
# 505 2021-05-28      -0.002180     -0.005348        -0.012081      -0.002467
#
#      Microsoft Return  Netflix Return Month Day of Week
# ...

# %%
sns.countplot(x='Month',data=returns, hue= 'Day of Week', palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
import matplotlib.pyplot as plt

# %%
pip install virtualenv

# %% [markdown]
# Conclusion
# As the spread of the virus is likely to continue disrupting economic activity and negatively impact manufacturing and service industries, especially in developed countries, we expect that financial markets will continue to be volatile. There is still a question as to whether this unfolding crisis will have a lasting structural impact on the global economy or largely short-term financial and economic consequences.

# %%
amazon_share = amazon.history(period="2y")
amazon_share.reset_index(inplace=True)
amazon_share.head()

# %%
Am = amazon_share['Open']

# %%
facebook_share = facebook.history(period="2y")
facebook_share.reset_index(inplace=True)
facebook_share.head()

# %%
Am = amazon_share['Open']

F = facebook_share['Open']

G = google_share['Open']

A = apple_share['Open']

# %%
plt.plot(t, G, 'r') # plotting t, a separately 
plt.plot(t, A, 'b') # plotting t, b separately 
plt.plot(t, F, 'y')
plt.plot(t, Am, 'g')

from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.figure(figsize=(40,18))
plt.show()

# %%
google_share = google.history(period="2y")
google_share_price_data.reset_index(inplace=True)
google_share_price_data.plot(x="Date", y="Open")

# %%
google_share_price_data[['Date','Close']]
google_share_price_data.reset_index(inplace=True)

# %%
Google = google.history(period="2y")
Google = Google['Close']
Google

# %%
Amazon = amazon.history(period="2y")
Amazon = Amazon['Close']
Amazon

# %%
df = Amazon
df['Google'] = Google
df

# %%
Facebook = facebook.history(period="2y")

# %%
Apple = apple.history(period="2y")

# %%
df = google_share_price_data[['Date','Close']]

# %%
df.head()

# %%
amd= yf.Ticker("AMD")

# %%
amd_info = amd.info
amd_info['country']

# %%
apple_share_price_data = apple.history(period="max")
apple_share_price_data['Volume'].max()
